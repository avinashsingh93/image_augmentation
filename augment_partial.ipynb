# %%
from imgaug import augmenters as iaa
import imgaug as ia
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
from imgaug import parameters as iap
import Augmentor

# %%
i_count=0
path='dataset'
images=cv2.imread('dataset/no_entry.jpg')

# %%
aug = iaa.OneOf([
    iaa.Affine(rotate=45),
    iaa.AdditiveGaussianNoise(scale=0.2*255),
    iaa.Add(50, per_channel=True),
    iaa.Sharpen(alpha=0.5)
])
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))
# True

# %%
 plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))

# %%
aug = iaa.SomeOf(2, [
    iaa.Affine(rotate=45),
    iaa.AdditiveGaussianNoise(scale=0.2*255),
    iaa.Add(50, per_channel=True),
    iaa.Sharpen(alpha=0.5)
])

# %%
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.AverageBlur(k=(2, 11))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.Sometimes(
      0.5,
      iaa.GaussianBlur(sigma=2.0),
      iaa.Sequential([iaa.Affine(rotate=45), iaa.Sharpen(alpha=1.0)])
  )

# %%
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.WithChannels(0, iaa.Add((10, 100)))

# %%
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
def img_func(images, random_state, parents, hooks):
    for img in images:
        img[::4] = 100
    return images

def keypoint_func(keypoints_on_images, random_state, parents, hooks):
    return keypoints_on_images

aug = iaa.Lambda(img_func, keypoint_func)
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.MedianBlur(k=(3, 11))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.GaussianBlur(sigma=(0.0, 3.0))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(images_aug)
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.Sharpen(alpha=(0.0, 1.0), lightness=(0.75, 2.0))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.Emboss(alpha=(0.0, 1.0), strength=(0.5, 1.5))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.AddElementwise((-40, 40))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.Multiply((0.5, 1.5))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.Dropout(p=(0, 0.2))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.CoarseDropout((0.0, 0.05), size_percent=(0.02, 0.25))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.Invert(0.5)
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.PiecewiseAffine(scale=(0.01, 0.05))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.PiecewiseAffine(scale=(0.03, 0.05))
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
aug = iaa.ElasticTransformation(alpha=(0, 5.0), sigma=0.25)
images_aug=aug.augment_images(images)
i_count+=1
cv2.imwrite(os.path.join(path , 'waka' +str(i_count)+'.jpg'), images_aug)
plt.imshow(cv2.cvtColor(images_aug, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\lenovo\Miniconda3\envs\kaggle\lib\site-packages\imgaug\augmenters\meta.py:379: UserWarning: You provided a numpy array of shape (2420, 2420, 3) as input to augment_images(), which was interpreted as (N, H, W). The last dimension however has value 1 or 3, which indicates that you provided a single image with shape (H, W, C) instead. If that is the case, you should use augment_image(image) or augment_images([image]), otherwise you will not get the expected augmentations.
#   "you will not get the expected augmentations." % (images_copy.shape,))

# %%
p = Augmentor.Pipeline("dataset")
# Point to a directory containing ground truth data.
# Images with the same file names will be added as ground truth data
# and augmented in parallel to the original data.
# Add operations to the pipeline as normal:
p.rotate(probability=1, max_left_rotation=10, max_right_rotation=10)
#p.flip_left_right(probability=0.5)
p.zoom_random(probability=0.5, percentage_area=0.8)
#p.flip_top_bottom(probability=0.5)
p.sample(200)
p.random_distortion(probability=1, grid_width=4, grid_height=4, magnitude=8)
p.sample(100)
p1 = Augmentor.Pipeline("dataset")
p1.random_erasing(probability=1,rectangle_area=0.2)
p1.sample(100)
# Out:
# Initialised with 19 image(s) found.
# Output directory set to dataset\output.
# Processing <PIL.Image.Image image mode=RGB size=2420x2420 at 0x2068F6699E8>: 100%|█| 200/200 [02:04<00:00,  1.94 Samples/s]
# Processing <PIL.Image.Image image mode=RGB size=2420x2420 at 0x2068F43AAC8>: 100%|█| 100/100 [01:32<00:00,  3.55 Samples/s]
# Initialised with 19 image(s) found.
# Output directory set to dataset\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2420x2420 at 0x2068F661BA8>: 100%|█| 100/100 [00:20<00:00,  8.18 Samples/s]
